# %%
import pandas as pd
df = pd.read_pickle(r'/GNN/processed/edge_friend_features.pkl')
print(df.shape)
print(df.columns.tolist())
print(df.head(10))
# Out:
# (155716, 8)
# ['inviter_id', 'voter_id', 'is_friend', 'share_count_a2b', 'share_count_b2a', 'total_interactions', 'last_share_days', 'response_rate']
#                          inviter_id                          voter_id  \
# 0  0000ec6f26ef7625d492ee3e57832a0f  bcc0a979710361b85213bfff1a009c51
# 1  000703f125be99b070a684af3bc06a22  9bab90679d74646445f2562497b3f104
# 2  000703f125be99b070a684af3bc06a22  ab839382f86a89dcfc484cf2e23c2731
# 3  000703f125be99b070a684af3bc06a22  cc88a1f93def52891e32e5d7ea02c708
# 4  000703f125be99b070a684af3bc06a22  d03d835a1fcf657bb577c9d7fd82cca4
# 5  000703f125be99b070a684af3bc06a22  f22b16f0151bada76076a6a6b732f110
# 6  0007ca9e703ed4c3b33cb5eea02c2567  0323fe85e5aa6d72cc64bfaeaf0c2535
# 7  0007ca9e703ed4c3b33cb5eea02c2567  24992053e03b4c6967fa639e8d29e764
# 8  0007ca9e703ed4c3b33cb5eea02c2567  2662bc737d39a15f9b44c37ea13c4e38
# 9  0007ca9e703ed4c3b33cb5eea02c2567  32900f4be8e0e6b333563406b105458a
#
# ...
